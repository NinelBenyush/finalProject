# %%
import pandas as pd
final_p = pd.read_csv("final_products.csv")

# %%
final_p.info()
final_p.set_index("code_p", inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         76 non-null     int64
#  1   code_p             76 non-null     int64
#  2   Inventory value    11 non-null     float64
#  3   Inventory          75 non-null     float64
#  4   Total orders       71 non-null     float64
#  5   total 23           69 non-null     float64
#  6   January            76 non-null     int64
#  7   February           76 non-null     int64
#  8   March              76 non-null     int64
#  9   April              76 non-null     int64
#  10  May                76 non-null     int64
#  11  June               76 non-null     int64
#  12  July               76 non-null     int64
#  13  August             76 non-null     int64
#  14  September          76 non-null     int64
#  15  October            76 non-null     int64
# ...

# %%
final_p
# Out:
#         Unnamed: 0  Inventory value  Inventory  Total orders  total 23  \
# code_p
# 15126            0              NaN        NaN           0.0     753.0
# 15127            1              NaN      477.0           0.0     241.0
# 15002            2              NaN      167.0           0.0     422.0
# 150022           3              NaN       93.0           0.0     108.0
# 150011           4              NaN      206.0           0.0     169.0
# ...            ...              ...        ...           ...       ...
# 15039           71              0.0        0.0         350.0     198.0
# 15040           72              NaN       59.0         150.0     120.0
# 15038           73              NaN      179.0           0.0     152.0
# 15041           74              NaN      158.0           0.0      54.0
# 15394           75              NaN       50.0           0.0       2.0
#
#         January  February  March  April  May  ...  name_p_SELINE  \
# ...

# %%
final_p.drop(columns=["Unnamed: 0"], inplace=True)
final_p
# Out:
#         Inventory value  Inventory  Total orders  total 23  January  February  \
# code_p
# 15126               NaN        NaN           0.0     753.0       39       134
# 15127               NaN      477.0           0.0     241.0       18        12
# 15002               NaN      167.0           0.0     422.0       66        43
# 150022              NaN       93.0           0.0     108.0        5        24
# 150011              NaN      206.0           0.0     169.0        5        33
# ...                 ...        ...           ...       ...      ...       ...
# 15039               0.0        0.0         350.0     198.0       18         7
# 15040               NaN       59.0         150.0     120.0       13        14
# 15038               NaN      179.0           0.0     152.0       26        39
# 15041               NaN      158.0           0.0      54.0        2         9
# 15394               NaN       50.0           0.0       2.0        0         0
#
# ...

# %%
final_p.to_csv('normalized_and_non_data.csv', index=True)

# %%
columns_to_drop = ['Inventory value', 'Inventory', 'Total orders', 'total 23', 'January', 'February', 'March', 'April','May','June','July','August','September','October','Novermber','December','AV23','multiplier','Minimum stock','purchase_r']
final_p_normalized = final_p.drop(columns=columns_to_drop)

# %%
final_p_normalized.to_csv('only_normalized_data.csv', index=False)

# %%
final_p
# Out:
#         Inventory value  Inventory  Total orders  total 23  January  February  \
# code_p
# 15126               NaN        NaN           0.0     753.0       39       134
# 15127               NaN      477.0           0.0     241.0       18        12
# 15002               NaN      167.0           0.0     422.0       66        43
# 150022              NaN       93.0           0.0     108.0        5        24
# 150011              NaN      206.0           0.0     169.0        5        33
# ...                 ...        ...           ...       ...      ...       ...
# 15039               0.0        0.0         350.0     198.0       18         7
# 15040               NaN       59.0         150.0     120.0       13        14
# 15038               NaN      179.0           0.0     152.0       26        39
# 15041               NaN      158.0           0.0      54.0        2         9
# 15394               NaN       50.0           0.0       2.0        0         0
#
# ...
